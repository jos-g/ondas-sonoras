# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon
import numpy as np
import os
import librosa as lr
import librosa.display
import IPython.display as ipd

# %%
f_s = 16000
N = 2*f_s
n = np.arange(N)
f_0 =330 #Hz
y = np.sin(2*np.pi*(f_0/f_s)*n) 
print("{:.2f} Hz".format(f_0))
ipd.Audio(rate=f_s, data=y)
# Out:
# 330.00 Hz
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
f_s = 16000
N = 2*f_s
n = np.arange(N)
f_0 =220 #Hz
y = np.sin(2*np.pi*(f_0/f_s)*n) + np.sin(2*np.pi*((3/2)*f_0/f_s)*n)
print("{:.2f} Hz".format(f_0))
ipd.Audio(rate=f_s, data=y)
# Out:
# 220.00 Hz
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
f_s = 16000
N = 2*f_s
n = np.arange(N)
f_0 =98 #Hz
y = np.sin(2*np.pi*(f_0/f_s)*n) + np.sin(2*np.pi*(2*f_0/f_s)*n) + np.sin(2*np.pi*(3*f_0/f_s)*n) + np.sin(2*np.pi*(4*f_0/f_s)*n)
+ np.sin(2*np.pi*(5*f_0/f_s)*n) + np.sin(2*np.pi*(6*f_0/f_s)*n)

print("{:.2f} Hz".format(f_0))
ipd.Audio(rate=f_s, data=y)
# Out:
# 98.00 Hz
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
f_s = 16000
N = 2*f_s
n = np.arange(N)
f_0 =98 #Hz
y =  np.sin(2*np.pi*(2*f_0/f_s)*n) + np.sin(2*np.pi*(3*f_0/f_s)*n) + np.sin(2*np.pi*(4*f_0/f_s)*n)
+ np.sin(2*np.pi*(5*f_0/f_s)*n) + np.sin(2*np.pi*(6*f_0/f_s)*n)

print("{:.2f} Hz".format(f_0))
ipd.Audio(rate=f_s, data=y)
# Out:
# 98.00 Hz
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Fs = 32000
f = 220
f_x = f/100
sample = 32000
x = np.arange(sample)
y = np.sin(np.pi*f_x*x/Fs) + np.sin(np.pi*2*f_x*x/Fs)+ np.sin(np.pi*3*f_x/Fs*x) +np.sin(np.pi*(7/2)*f_x/Fs*x)
plt.figure(figsize=(12.5,5))
plt.plot(x, y, color='black')
#plt.xlabel('Tempo (s)', fontsize=12)
plt.ylabel('Amplitude', fontsize=12)
#plt.title('Onda Senoidal com f = 330 Hz')
plt.grid(True, which='both')
plt.axhline(y=0, color='k')
plt.show()

# %%
# Todas as frequências
f1 = 98
f2 = 2*f1
f3 = 3*f1
f4 = 4*f1
f5 = 5*f1
f6 = 6*f1
f7 = 7*f1
fx1 = f1/100 
fx2 = f2/100 
fx3 = f3/100 
fx4 = f4/100 
fx5 = f5/100 
fx6 = f6/100 
fx7 = f7/100
y1 = np.sin(2*np.pi*fx1*x/Fs)
y2 = np.sin(2*np.pi*fx2*x/Fs)
y3 = np.sin(2*np.pi*fx3*x/Fs)
y4 = np.sin(2*np.pi*fx4*x/Fs)
y5 = np.sin(2*np.pi*fx5*x/Fs)
y6 = np.sin(2*np.pi*fx6*x/Fs)
y7 = y6 = np.sin(2*np.pi*fx7*x/Fs)
ys = y2 + y4 + y6 + y7

# %%
plt.figure(figsize=(20,10))
plt.plot(x, y1, color='red', label='f = 110hz', alpha=1)
plt.plot(x, y2, color='blue', label='f = 220hz', alpha=0.3)
#plt.plot(x, y3, color='pink', label='f = 330hz', alpha=0.3)
plt.plot(x, y4, color='orange', label='f = 440hz', alpha=0.3)
#plt.plot(x, y5, color='violet', label='f = 550hz', alpha=0.3)
plt.plot(x, y6, color='red', label='f = 660hz', alpha=0.3)
plt.plot(x,y7,color='green', label='770hz', alpha=0.3)
plt.plot(x,ys,color='black', label='Soma', alpha=1)
#plt.xlabel('Tempo (s)', fontsize=14)
plt.ylabel('Amplitude', fontsize=14)
plt.title('Frequências usadas')
plt.grid(True, which='both')
plt.axhline(y=0, color='k')
plt.legend(bbox_to_anchor = (1,1), loc='upper center')
plt.show()
